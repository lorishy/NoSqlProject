# %%
import pandas as pd
from pymongo import MongoClient
import pprint
import json

# %%
DatabaseFootball = pd.read_csv('Data.csv')

# %%
DatabaseFootball
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
# Afficher tous les différents pays dans la colonne "Country"
unique_countries = DatabaseFootball['Country'].unique()

# Afficher la liste des pays uniques
print("Liste des pays uniques :")
for country in unique_countries:
    print(country)
# Out:
# Liste des pays uniques :
# Spain
# Italy
# Germany
# England
# Brazil
# France
# USA
# Portugal
#  Netherlands

# %%
# Filtrer les lignes pour exclure "USA" et "Brazil"
filtered_data = DatabaseFootball.query('Country not in ["USA", "Brazil"]')

# Afficher les premières lignes du DataFrame filtré
print(filtered_data.head())
# Out:
#   Country   League   Club       Player Names  Matches_Played  Substitution   \
# 0   Spain  La Liga  (BET)    Juanmi Callejon              19             16
# 1   Spain  La Liga  (BAR)  Antoine Griezmann              36              0
# 2   Spain  La Liga  (ATL)        Luis Suarez              34              1
# 3   Spain  La Liga  (CAR)       Ruben Castro              32              3
# 4   Spain  La Liga  (VAL)      Kevin Gameiro              21             10
#
#    Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0  1849     11   6.62              0.34     48        20                 2.47
# 1  3129     16  11.86              0.36     88        41                 2.67
# 2  2940     28  23.21              0.75    120        57                 3.88
# 3  2842     13  14.06              0.47    117        42                 3.91
# 4  1745     13  10.65              0.58     50        23                 2.72
#
#    On Target Per Avg Match  Year
# ...

# %%
DatabaseFootball
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
DatabaseFootball = filtered_data

# %%
DatabaseFootball
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
for col in DatabaseFootball.columns:
    if DatabaseFootball[col].isna().sum()>0:
        print("la colonne {} a ".format(col),DatabaseFootball[col].isna().sum(),"null")
# Out:
# la colonne Club a  15 null

# %%
DatabaseFootball.isnull().sum()
# Out:
# Country                     0
# League                      0
# Club                       15
# Player Names                0
# Matches_Played              0
# Substitution                0
# Mins                        0
# Goals                       0
# xG                          0
# xG Per Avg Match            0
# Shots                       0
# OnTarget                    0
# Shots Per Avg Match         0
# On Target Per Avg Match     0
# Year                        0
# dtype: int64

# %%
# Supprimer les lignes où la valeur de la colonne "Club" est nulle
DatabaseFootball = DatabaseFootball.dropna(subset=['Club'])

# %%
# Afficher les premières lignes du DataFrame après la suppression des lignes nulles
print(DatabaseFootball.head())
# Out:
#   Country   League   Club       Player Names  Matches_Played  Substitution   \
# 0   Spain  La Liga  (BET)    Juanmi Callejon              19             16
# 1   Spain  La Liga  (BAR)  Antoine Griezmann              36              0
# 2   Spain  La Liga  (ATL)        Luis Suarez              34              1
# 3   Spain  La Liga  (CAR)       Ruben Castro              32              3
# 4   Spain  La Liga  (VAL)      Kevin Gameiro              21             10
#
#    Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0  1849     11   6.62              0.34     48        20                 2.47
# 1  3129     16  11.86              0.36     88        41                 2.67
# 2  2940     28  23.21              0.75    120        57                 3.88
# 3  2842     13  14.06              0.47    117        42                 3.91
# 4  1745     13  10.65              0.58     50        23                 2.72
#
#    On Target Per Avg Match  Year
# ...

# %%
DatabaseFootball.isnull().sum()
# Out:
# Country                    0
# League                     0
# Club                       0
# Player Names               0
# Matches_Played             0
# Substitution               0
# Mins                       0
# Goals                      0
# xG                         0
# xG Per Avg Match           0
# Shots                      0
# OnTarget                   0
# Shots Per Avg Match        0
# On Target Per Avg Match    0
# Year                       0
# dtype: int64

# %%
DatabaseFootball
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 654   Netherlands  Eredivisie  (RZA)       Haris Vuckic              23
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
documents = DatabaseFootball.to_dict('records')

# %%
client = MongoClient()

# %%
DbFoot = client['IPSSI']['DbFootball']

# %%
DbFoot.insert_many(documents)
# Out:
# InsertManyResult([ObjectId('65afa8da1114d2f62fa1baa5'), ObjectId('65afa8da1114d2f62fa1baa6'), ObjectId('65afa8da1114d2f62fa1baa7'), ObjectId('65afa8da1114d2f62fa1baa8'), ObjectId('65afa8da1114d2f62fa1baa9'), ObjectId('65afa8da1114d2f62fa1baaa'), ObjectId('65afa8da1114d2f62fa1baab'), ObjectId('65afa8da1114d2f62fa1baac'), ObjectId('65afa8da1114d2f62fa1baad'), ObjectId('65afa8da1114d2f62fa1baae'), ObjectId('65afa8da1114d2f62fa1baaf'), ObjectId('65afa8da1114d2f62fa1bab0'), ObjectId('65afa8da1114d2f62fa1bab1'), ObjectId('65afa8da1114d2f62fa1bab2'), ObjectId('65afa8da1114d2f62fa1bab3'), ObjectId('65afa8da1114d2f62fa1bab4'), ObjectId('65afa8da1114d2f62fa1bab5'), ObjectId('65afa8da1114d2f62fa1bab6'), ObjectId('65afa8da1114d2f62fa1bab7'), ObjectId('65afa8da1114d2f62fa1bab8'), ObjectId('65afa8da1114d2f62fa1bab9'), ObjectId('65afa8da1114d2f62fa1baba'), ObjectId('65afa8da1114d2f62fa1babb'), ObjectId('65afa8da1114d2f62fa1babc'), ObjectId('65afa8da1114d2f62fa1babd'), ObjectId('65afa8da1114d2f62fa1
# ...

# %%
DatabaseFootball['League'].unique()
# Out:
# array(['La Liga', 'Serie A', 'Bundesliga', 'Premier League',
#        'France Ligue 11', 'France Ligue 20', 'France Ligue 2',
#        'France Ligue 12', 'France Ligue 9', 'France Ligue 15',
#        'France Ligue 6', 'France Ligue 3', 'France Ligue 16',
#        'France Ligue 14', 'France Ligue 4', 'France Ligue 1',
#        'France Ligue 10', 'France Ligue 7', 'France Ligue 13',
#        'France Ligue 8', 'France Ligue 5', 'France Ligue 19',
#        'France Ligue 18', 'France Ligue 17', 'Primeira Liga',
#        'Eredivisie'], dtype=object)
